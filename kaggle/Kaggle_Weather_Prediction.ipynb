# %% [markdown]
# # Rain in Australia

# %% [markdown]
# ## Dataset Reference
# https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package/data

# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# ### Read Data and Describe Dataset

# %%
df = pd.read_csv('weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df["RainTomorrow"].value_counts()
# Out:
# RainTomorrow
# 0    113583
# 1     31877
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df["RainTomorrow"] = (df["RainTomorrow"] == "Yes").astype(int)
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
cols = []
for i in df.columns:
    cols.append(i)
cols
# Out:
# ['Date',
#  'Location',
#  'MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustDir',
#  'WindGustSpeed',
#  'WindDir9am',
#  'WindDir3pm',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'RainToday',
#  'RainTomorrow']

# %% [markdown]
# ### Plot Data

# %%
for label in cols[:-1]:
  if df[label].dtype in ['object', 'category']:  # Check if column is of string/categorical type
    plt.hist(df[df["RainTomorrow"] == 1][label], color="red", label='Yes', alpha=0.7, density=True)
    plt.hist(df[df["RainTomorrow"] == 0][label], color="green", label='No', alpha=0.7, density=True)
    plt.title(label)
    plt.ylabel("Rain Chance")
    plt.xlabel(label)
    plt.legend()
    plt.show()
  else:
    print(f"Skipping column '{label}' because it is not of type string/categorical.")  # Inform the user about skipped columns
# Out:
# Skipping column 'MinTemp' because it is not of type string/categorical.
# Skipping column 'MaxTemp' because it is not of type string/categorical.
# Skipping column 'Rainfall' because it is not of type string/categorical.
# Skipping column 'Evaporation' because it is not of type string/categorical.
# Skipping column 'Sunshine' because it is not of type string/categorical.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-1956756e6ed6> in <cell line: 1>()
#       1 for label in cols[:-1]:
#       2   if df[label].dtype in ['object', 'category']:  # Check if column is of string/categorical type
# ----> 3     plt.hist(df[df["RainTomorrow"] == 1][label], color="red", label='Yes', alpha=0.7, density=True)
#       4     plt.hist(df[df["RainTomorrow"] == 0][label], color="green", label='No', alpha=0.7, density=True)
#       5     plt.title(label)
#
# ...
